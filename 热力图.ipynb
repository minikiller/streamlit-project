# %% [raw]
# ---
# title: 查看板块热力图
# description: 根据日期查询生成
# show-code: False
# params:
#     cur_date:
#         input: text
#         label: 请输入股票日期
#         value: 2023/03/01
#     filter_value:
#         input: text
#         label: 请输入过滤的板块名称，逗号分隔
#         value: 包装印刷, 中药
#     start_value:
#         input: text
#         label: 请输入过滤的最小值，单位：亿元
#         value: 10
#     end_value:
#         input: text
#         label: 请输入过滤的最大值，单位：亿元
#         value: 100
#     test_value:
#         input: numeric
#         label: This is numeric label
#         value: 5.5
#         min: 0.0
#         max: 10.0
#         step: 0.1
# ---

# %% [markdown]
# ## 变量定义

# %%
cur_date="2023-03-01"
filter_value = "包装印刷,中药"
start_value="10"
end_value="100"

# %%
from datetime import datetime

# get the current datetime object
now = datetime.now()

# format the datetime object
cur_Date = now.strftime("%Y-%m-%d")
cur_Date
# Out:
# '2023-03-14'

# %%
import pandas as pd
df = pd.read_csv(
    f"../data/hist_{cur_Date}.csv", parse_dates=['日期'], index_col=0, dtype={"股票编号": object})
# df.drop("Unnamed: 0", inplace=True, axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 45896 entries, 2023-03-10 to 2023-03-13
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   开盘      45896 non-null  float64
#  1   收盘      45896 non-null  float64
#  2   最高      45896 non-null  float64
#  3   最低      45896 non-null  float64
#  4   成交量     45896 non-null  float64
#  5   成交额     45896 non-null  float64
#  6   振幅      45896 non-null  float64
#  7   涨跌幅     45896 non-null  float64
#  8   涨跌额     45896 non-null  float64
#  9   换手率     45896 non-null  float64
#  10  股票编号    45896 non-null  object
#  11  板块名称    45864 non-null  object
# dtypes: float64(10), object(2)
# memory usage: 4.6+ MB

# %% [markdown]
# ## 去掉板块名称是null的数据

# %%
null_rows = df[df.isnull().any(axis=1)]
null_rows
# Out:
#                开盘     收盘     最高     最低       成交量           成交额     振幅    涨跌幅  \
# 日期
# 2023-03-10   5.26   6.31   6.31   5.26   41630.0  2.614419e+07  23.97  44.06
# 2023-03-13   6.94   6.94   6.94   6.94   15270.0  1.059735e+07   0.00   9.98
# 2023-03-13  13.76  16.52  16.52  13.76   12054.0  1.986041e+07  24.06  44.03
# 2023-03-01  20.73  20.66  20.78  20.44   85842.0  1.770008e+08   1.66   0.93
# 2023-03-02  20.58  20.25  20.58  20.22   77343.0  1.572681e+08   1.74  -1.98
# 2023-03-03  20.34  20.30  20.42  20.12   55779.0  1.129975e+08   1.48   0.25
# 2023-03-06  20.21  20.19  20.37  20.13   65178.0  1.318315e+08   1.18  -0.54
# 2023-03-07  20.16  19.74  20.29  19.74   79620.0  1.593523e+08   2.72  -2.23
# 2023-03-08  19.71  19.90  19.95  19.66   36906.0  7.316921e+07   1.47   0.81
# 2023-03-09  19.92  19.84  20.10  19.77   37777.0  7.515251e+07   1.66  -0.30
# 2023-03-10  19.75  19.52  19.76  19.48   46564.0  9.118927e+07   1.41  -1.61
# 2023-03-13  19.52  19.66  19.67  19.37   44782.0  8.759593e+07   1.54   0.72
# 2023-03-01   6.76   6.72   6.84   6.66  176275.0  1.183468e+08   2.65  -0.88
# 2023-03-02   6.72   6.73   6.75   6.62  162047.0  1.084726e+08   1.93   0.15
# 2023-03-03   6.74   6.90   6.94   6.70  242454.0  1.655939e+08   3.57   2.53
# 2023-03-06   6.92   6.99   7.02   6.90  210405.0  1.467860e+08   1.74   1.30
# 2023-03-07   7.03   6.74   7.04   6.73  252563.0  1.732905e+08   4.43  -3.58
# 2023-03-08   6.75   6.81   6.84   6.70  137341.0  9.312001e+07   2.08   1.04
# 2023-03-09   6.82   6.82   6.88   6.75   89652.0  6.108738e+07   1.91   0.15
# 2023-03-10   6.82   6.71   6.82   6.66  145111.0  9.753649e+07   2.35  -1.61
# 2023-03-13   6.79   7.04   7.05   6.74  380812.0  2.646758e+08   4.62   4.92
# 2023-03-01  15.70  15.70  15.80  15.56  122948.0  1.927931e+08   1.54   0.96
# 2023-03-02  15.71  15.68  15.76  15.60   56870.0  8.921611e+07   1.02  -0.13
# 2023-03-03  15.67  15.72  15.76  15.63   53679.0  8.431765e+07   0.83   0.26
# 2023-03-06  15.72  15.66  15.79  15.66   60066.0  9.444290e+07   0.83  -0.38
# 2023-03-07  15.66  15.40  15.76  15.39   76516.0  1.193150e+08   2.36  -1.66
# 2023-03-08  15.38  15.39  15.46  15.28   52803.0  8.116055e+07   1.17  -0.06
# 2023-03-09  15.37  15.35  15.46  15.32   38412.0  5.906822e+07   0.91  -0.26
# 2023-03-10  15.33  15.17  15.33  15.12   49658.0  7.548921e+07   1.37  -1.17
# 2023-03-13  15.15  15.26  15.27  15.12   45564.0  6.925833e+07   0.99   0.59
# 2023-03-10   4.29   4.09   4.68   4.09  336951.0  1.470118e+08  17.46  21.01
# 2023-03-13   3.68   3.44   3.72   3.41  172743.0  6.106851e+07   7.58 -15.89
#
#              涨跌额    换手率    股票编号 板块名称
# 日期
# 2023-03-10  1.93   2.08  601121  NaN
# 2023-03-13  0.63   0.76  601121  NaN
# 2023-03-13  5.05   2.19  603153  NaN
# 2023-03-01  0.19   0.78  603858  NaN
# 2023-03-02 -0.41   0.70  603858  NaN
# 2023-03-03  0.05   0.50  603858  NaN
# 2023-03-06 -0.11   0.59  603858  NaN
# 2023-03-07 -0.45   0.72  603858  NaN
# 2023-03-08  0.16   0.33  603858  NaN
# 2023-03-09 -0.06   0.34  603858  NaN
# 2023-03-10 -0.32   0.42  603858  NaN
# 2023-03-13  0.14   0.40  603858  NaN
# 2023-03-01 -0.06   2.29  600351  NaN
# 2023-03-02  0.01   2.10  600351  NaN
# 2023-03-03  0.17   3.15  600351  NaN
# 2023-03-06  0.09   2.73  600351  NaN
# 2023-03-07 -0.25   3.28  600351  NaN
# 2023-03-08  0.07   1.78  600351  NaN
# 2023-03-09  0.01   1.16  600351  NaN
# 2023-03-10 -0.11   1.88  600351  NaN
# 2023-03-13  0.33   4.95  600351  NaN
# 2023-03-01  0.15   1.06  000623  NaN
# 2023-03-02 -0.02   0.49  000623  NaN
# 2023-03-03  0.04   0.46  000623  NaN
# 2023-03-06 -0.06   0.52  000623  NaN
# 2023-03-07 -0.26   0.66  000623  NaN
# 2023-03-08 -0.01   0.46  000623  NaN
# 2023-03-09 -0.04   0.33  000623  NaN
# 2023-03-10 -0.18   0.43  000623  NaN
# 2023-03-13  0.09   0.39  000623  NaN
# 2023-03-10  0.71  58.07  872541  NaN
# 2023-03-13 -0.65  29.77  872541  NaN

# %%
df.dropna(inplace=True)

# %% [markdown]
# ## 根据条件过滤数据

# %%
# df['涨跌幅'] = df['收盘价'].pct_change()
cur_df = df.loc[cur_date]
_list = filter_value.split(",")
cur_df = cur_df[~cur_df['板块名称'].isin(_list)]
cur_df = cur_df[(cur_df['成交额'] >= int(start_value)*100_000_000)
                & (cur_df['成交额'] <= int(end_value)*100_000_000)]
cur_df
# Out:
#                 开盘      收盘      最高     最低        成交量           成交额     振幅  \
# 日期
# 2023-03-01   55.55   60.40   64.85  55.00   253104.0  1.456401e+09  21.10
# 2023-03-01    9.95   10.43   10.52   9.92  1517271.0  1.566560e+09   5.95
# 2023-03-01   28.96   30.20   30.30  28.52   902575.0  2.659341e+09   6.09
# 2023-03-01   19.51   21.30   21.89  19.51   583281.0  1.223749e+09  11.96
# 2023-03-01   83.59   90.60   92.55  83.10   129395.0  1.146263e+09  11.25
# ...            ...     ...     ...    ...        ...           ...    ...
# 2023-03-01   38.50   42.88   42.90  38.41  2225963.0  9.255820e+09  11.51
# 2023-03-01  102.45  101.05  105.15  97.80   209708.0  2.129538e+09   7.50
# 2023-03-01   15.00   14.73   15.49  14.66  1758843.0  2.642249e+09   5.45
# 2023-03-01   13.07   12.77   13.28  12.40  1027373.0  1.307955e+09   6.57
# 2023-03-01   51.88   52.38   54.99  51.58   501263.0  2.671044e+09   6.51
#
#               涨跌幅    涨跌额    换手率    股票编号     板块名称
# 日期
# 2023-03-01  29.39  13.72  70.71  688522     军工电子
# 2023-03-01   3.47   0.35  13.43  600095       证券
# 2023-03-01   3.35   0.98   7.63  600118     航天装备
# 2023-03-01   7.04   1.40  22.94  603083  通信终端及配件
# 2023-03-01   7.90   6.63   5.34  688256   集成电路设计
# ...           ...    ...    ...     ...      ...
# 2023-03-01   9.95   3.88  15.23  000977    计算机设备
# 2023-03-01   3.11   3.05  59.35  001311    汽车零部件
# 2023-03-01  -3.35  -0.51  35.67  002229       印刷
# 2023-03-01  -4.70  -0.63  39.75  002112    输变电设备
# 2023-03-01   0.00   0.00   8.49  300114     军工电子
#
# [134 rows x 12 columns]

# %%
# 按股票名称分组，并统计涨幅大于0和小于0的股票数量
result = cur_df.groupby('板块名称')['涨跌幅'].agg(
    [('涨的数量', lambda x: sum(x > 0)), ('跌的数量', lambda x: sum(x < 0))])
result
# Out:
#         涨的数量  跌的数量
# 板块名称
# IT服务      12     0
# 专业工程       1     0
# 乘用车        3     0
# 乳品         1     0
# 休闲食品       1     0
# ...      ...   ...
# 集成电路封测     2     0
# 集成电路设计     3     1
# 非金属材料Ⅲ     0     1
# 面板         1     0
# 餐饮         1     0
#
# [64 rows x 2 columns]

# %%
import plotly.graph_objs as go

# 将结果转换为 Pandas DataFrame
# result_df = result.loc[['IT服务', 'LED']].reset_index()

# 获得前十条数据
result_df = result.iloc[:10].reset_index()

# result_df = result.iloc[:10].reset_index()

# 绘制柱状图
fig = go.Figure(data=[
    go.Bar(name='涨的数量', x=result_df['板块名称'], y=result_df['涨的数量']),
    go.Bar(name='跌的数量', x=result_df['板块名称'], y=result_df['跌的数量'])
])

# 设置图表布局和标题
fig.update_layout(title='涨跌幅统计图', xaxis_title='板块名称', yaxis_title='数量')

# 显示图表
fig.show()

# %%
def round_age(code):
    return result.loc[code]['涨的数量']


def unround_age(code):
    return result.loc[code]['跌的数量']


cur_df['涨的数量'] = cur_df['板块名称'].apply(lambda row: round_age(row))
cur_df['跌的数量'] = cur_df['板块名称'].apply(lambda row: unround_age(row))

# %%
import plotly.express as px
fig = px.treemap(cur_df, path=[px.Constant('All'), '板块名称'], values='成交额', height=1080, width=1920,
                 color='涨跌幅', color_continuous_scale='Geyser', range_color=[-0.05, 0.05], color_continuous_midpoint=0,
                 hover_data={"涨跌幅": ':.2%', "成交额": ':.2f', "涨的数量": ":,", "跌的数量": ":,"})
fig.update_traces(textinfo="label+value", textfont=dict(size=24))
fig.show()
