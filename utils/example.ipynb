# %%
import pandas as pd

# %%
df = pd.read_csv(
            f"../data/Hist_2023-04-30.csv", parse_dates=['日期'], index_col=0, dtype={"股票代码": object})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 61051 entries, 2023-04-03 to 2023-04-19
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   开盘      61051 non-null  float64
#  1   收盘      61051 non-null  float64
#  2   最高      61051 non-null  float64
#  3   最低      61051 non-null  float64
#  4   成交量     61051 non-null  int64
#  5   成交额     61051 non-null  float64
#  6   振幅      61051 non-null  float64
#  7   涨跌幅     61051 non-null  float64
#  8   涨跌额     61051 non-null  float64
#  9   换手率     61051 non-null  float64
#  10  板块名称    61051 non-null  object
#  11  股票代码    61051 non-null  object
# dtypes: float64(9), int64(1), object(2)
# memory usage: 6.1+ MB

# %%
df = df.drop(columns=["板块名称"])

# %%
df.index
# Out:
# DatetimeIndex(['2023-04-03', '2023-04-04', '2023-04-06', '2023-04-07',
#                '2023-04-10', '2023-04-11', '2023-04-12', '2023-04-13',
#                '2023-04-14', '2023-04-17',
#                ...
#                '2023-04-06', '2023-04-07', '2023-04-10', '2023-04-11',
#                '2023-04-12', '2023-04-13', '2023-04-14', '2023-04-17',
#                '2023-04-18', '2023-04-19'],
#               dtype='datetime64[ns]', name='日期', length=61051, freq=None)

# %%
stock='东方财富'
category='概念'
sector_df = pd.read_csv(f"../data/constant/{stock}_{category}名称_股票对应.csv",
                                index_col=0, dtype={"股票代码": object})

        # df_list.append(sector_df)
df.reset_index(inplace=True)
merged_df = pd.merge(df, sector_df, on='股票代码')
# merged_df = pd.merge(df, sector_df, on='股票代码',how='outer', left_index=True)
merged_df
# Out:
#                日期     开盘     收盘     最高     最低    成交量          成交额    振幅   涨跌幅  \
# 0      2023-04-03  21.53  21.59  22.37  21.53  49386  108092639.0  3.88 -0.23
# 1      2023-04-03  21.53  21.59  22.37  21.53  49386  108092639.0  3.88 -0.23
# 2      2023-04-03  21.53  21.59  22.37  21.53  49386  108092639.0  3.88 -0.23
# 3      2023-04-03  21.53  21.59  22.37  21.53  49386  108092639.0  3.88 -0.23
# 4      2023-04-03  21.53  21.59  22.37  21.53  49386  108092639.0  3.88 -0.23
# ...           ...    ...    ...    ...    ...    ...          ...   ...   ...
# 534374 2023-04-19  11.90  11.96  12.02  11.83  22119   26370227.0  1.59  0.25
# 534375 2023-04-19  11.90  11.96  12.02  11.83  22119   26370227.0  1.59  0.25
# 534376 2023-04-19  11.90  11.96  12.02  11.83  22119   26370227.0  1.59  0.25
# 534377 2023-04-19  11.90  11.96  12.02  11.83  22119   26370227.0  1.59  0.25
# 534378 2023-04-19  11.90  11.96  12.02  11.83  22119   26370227.0  1.59  0.25
#
# ...
