# %% [markdown]
# ## 获得当月的股票信息

# %%
import pandas as pd
import akshare as ak

# %%
code_df = pd.read_csv("../data/板块名称_股票对应.csv", index_col=0)
code_dict = code_df.set_index("代码")['板块名称'].to_dict()
code_dict
# Out:
# {'300119': '动物保健',
#  '002141': '动物保健',
#  '300021': '农业综合',
#  '600201': '动物保健',
#  '688098': '动物保健',
#  '300871': '动物保健',
#  '603718': '动物保健',
#  '600195': '动物保健',
#  '002556': '农业综合',
#  '838275': '动物保健',
#  '839729': '动物保健',
#  '830964': '农业综合',
#  '002688': '动物保健',
#  '603566': '动物保健',
#  '002868': '动物保健',
#  '688526': '动物保健',
#  '300761': '畜禽养殖',
#  '000735': '畜禽养殖',
#  '002157': '畜禽养殖',
#  '001201': '畜禽养殖',
#  '002714': '畜禽养殖',
#  '002069': '水产养殖',
#  '605296': '畜禽养殖',
#  '300967': '畜禽养殖',
#  '002124': '畜禽养殖',
#  '002982': '畜禽养殖',
#  '603477': '畜禽养殖',
#  '600097': '海洋捕捞',
#  '300498': '畜禽养殖',
#  '600965': '畜禽养殖',
#  '002299': '畜禽养殖',
#  '600975': '畜禽养殖',
#  '600467': '水产养殖',
#  '600257': '水产养殖',
#  '002321': '畜禽养殖',
#  '300094': '水产养殖',
#  '002234': '畜禽养殖',
#  '002458': '畜禽养殖',
#  '000798': '海洋捕捞',
#  '002746': '畜禽养殖',
#  '300313': '畜禽养殖',
#  '600758': '煤炭开采',
#  '601225': '煤炭开采',
#  '600971': '煤炭开采',
#  '601699': '煤炭开采',
#  '600397': '煤炭开采',
#  '601918': '煤炭开采',
# ...

# %%
items = []
for key, value in code_dict.items():
    stock_zh_a_hist_df = ak.stock_zh_a_hist(
        symbol=key, period="daily", start_date="20230301", end_date='20230302', adjust="")
    stock_zh_a_hist_df['股票编号'] = key
    stock_zh_a_hist_df['板块名称'] = code_dict.get(key)
    items.append(stock_zh_a_hist_df)

# %%
df = pd.DataFrame()
df = pd.concat(items, axis=0)
df.info()

# %%
df.to_csv("data/hist_2023-03-14.csv",index=False)

# %% [markdown]
# ## 获得独立的股票数据

# %%
import akshare as ak
a_hist_df = ak.stock_zh_a_hist(
        symbol="603189", period="daily", start_date="20221001", end_date='20230501', adjust="")
a_hist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   日期      132 non-null    object
#  1   开盘      132 non-null    float64
#  2   收盘      132 non-null    float64
#  3   最高      132 non-null    float64
#  4   最低      132 non-null    float64
#  5   成交量     132 non-null    int64
#  6   成交额     132 non-null    float64
#  7   振幅      132 non-null    float64
#  8   涨跌幅     132 non-null    float64
#  9   涨跌额     132 non-null    float64
#  10  换手率     132 non-null    float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 11.5+ KB

# %%
a_hist_df.head()
# Out:
#            日期     开盘     收盘     最高     最低    成交量         成交额    振幅   涨跌幅  \
# 0  2022-10-10  11.09  10.86  11.18  10.81   8747   9602030.0  3.33 -2.16
# 1  2022-10-11  10.85  11.00  11.10  10.76   7330   8013626.0  3.13  1.29
# 2  2022-10-12  11.00  11.48  11.50  10.84  11708  13096576.0  6.00  4.36
# 3  2022-10-13  11.48  11.93  11.95  11.41  20012  23591869.0  4.70  3.92
# 4  2022-10-14  12.00  12.10  12.18  11.90  18585  22349003.0  2.35  1.42
#
#     涨跌额   换手率
# 0 -0.24  0.32
# 1  0.14  0.27
# 2  0.48  0.43
# 3  0.45  0.74
# 4  0.17  0.69

# %%
a_hist_df.rename(columns={"日期":"date","开盘":"open","收盘":"close","最高":"high","最低":"low",},inplace=True)
a_hist_df
# Out:
#            date   open  close   high    low    成交量          成交额    振幅   涨跌幅  \
# 0    2022-10-10  11.09  10.86  11.18  10.81   8747    9602030.0  3.33 -2.16
# 1    2022-10-11  10.85  11.00  11.10  10.76   7330    8013626.0  3.13  1.29
# 2    2022-10-12  11.00  11.48  11.50  10.84  11708   13096576.0  6.00  4.36
# 3    2022-10-13  11.48  11.93  11.95  11.41  20012   23591869.0  4.70  3.92
# 4    2022-10-14  12.00  12.10  12.18  11.90  18585   22349003.0  2.35  1.42
# ..          ...    ...    ...    ...    ...    ...          ...   ...   ...
# 127  2023-04-14  18.08  17.71  18.28  17.42  73765  130721507.0  4.78 -1.61
# 128  2023-04-17  17.54  16.78  17.63  16.71  97348  164872278.0  5.19 -5.25
# 129  2023-04-18  16.88  16.60  16.88  16.26  49787   82408184.0  3.69 -1.07
# 130  2023-04-19  16.55  16.75  17.19  16.51  56868   96104134.0  4.10  0.90
# 131  2023-04-20  16.70  16.86  16.97  16.70  38264   64476634.0  1.61  0.66
#
#       涨跌额   换手率
# 0   -0.24  0.32
# 1    0.14  0.27
# ...

# %%
a_hist_df.to_csv("603189.csv",index=False)
