# %%
import pandas as pd
from datetime import datetime

# %%
 
df = pd.read_csv(
    "../data/Hist_2023-03-25.csv", parse_dates=['日期'], index_col=0, dtype={"股票编号": object})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 91506 entries, 2023-03-01 to 2023-03-24
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   开盘      91506 non-null  float64
#  1   收盘      91506 non-null  float64
#  2   最高      91506 non-null  float64
#  3   最低      91506 non-null  float64
#  4   成交量     91506 non-null  int64
#  5   成交额     91506 non-null  float64
#  6   振幅      91506 non-null  float64
#  7   涨跌幅     91506 non-null  float64
#  8   涨跌额     91506 non-null  float64
#  9   换手率     91506 non-null  float64
#  10  板块名称    91506 non-null  object
#  11  股票代码    91506 non-null  int64
# dtypes: float64(9), int64(2), object(1)
# memory usage: 9.1+ MB

# %%
data=df.loc["2023-03-24"]
data
# Out:
#                开盘     收盘     最高     最低     成交量          成交额    振幅   涨跌幅   涨跌额  \
# 日期
# 2023-03-24  20.40  21.03  21.23  20.30   46779   97837140.1  4.56  3.09  0.63
# 2023-03-24   4.31   4.33   4.35   4.30   52031   22498401.0  1.16  0.23  0.01
# 2023-03-24   4.91   4.85   4.91   4.84   91069   44265053.0  1.42 -1.42 -0.07
# 2023-03-24  10.94  10.70  11.08  10.68  161072  174093139.0  3.66 -2.10 -0.23
# 2023-03-24   8.05   8.13   8.17   8.05   13803   11202546.0  1.49  0.62  0.05
# ...           ...    ...    ...    ...     ...          ...   ...   ...   ...
# 2023-03-24  15.06  14.98  15.06  14.87    2286    3420938.0  1.27  0.20  0.03
# 2023-03-24   3.91   3.94   4.00   3.89   75331   29660289.0  2.80  0.25  0.01
# 2023-03-24  10.25  10.25  10.31  10.20  141095  144551683.0  1.07  0.00  0.00
# 2023-03-24  10.01  10.05  10.11   9.96  119530  120025603.6  1.49  0.10  0.01
# 2023-03-24  13.02  13.12  13.23  13.02   24333   31929546.0  1.61  0.61  0.08
#
# ...

# %%
len(data['板块名称'].unique())
# Out:
# 235

# %%
data[data['板块名称']=="农业服务"]
# Out:
# Empty DataFrame
# Columns: [开盘, 收盘, 最高, 最低, 成交量, 成交额, 振幅, 涨跌幅, 涨跌额, 换手率, 板块名称, 股票代码]
# Index: []

# %%
merge_df = pd.read_csv(
    "../data/merge_2023-03-25.csv", parse_dates=['日期'], index_col=0, dtype={"股票代码": object})
value = pd.read_csv("../data/总股本.csv", index_col=0, dtype={"股票代码": object})
value_dict = value['总股本'].to_dict()
merge_df['总股本'] = merge_df['股票代码'].apply(lambda x: value_dict.get(x))
merge_df['总市值'] = merge_df['总股本']*merge_df['收盘']
merge_df.fillna(0, inplace=True)
merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 170816 entries, 2023-03-01 to 2023-03-24
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   开盘      170816 non-null  float64
#  1   收盘      170816 non-null  float64
#  2   最高      170816 non-null  float64
#  3   最低      170816 non-null  float64
#  4   成交量     170816 non-null  int64
#  5   成交额     170816 non-null  float64
#  6   振幅      170816 non-null  float64
#  7   涨跌幅     170816 non-null  float64
#  8   涨跌额     170816 non-null  float64
#  9   换手率     170816 non-null  float64
#  10  股票代码    170816 non-null  object
#  11  股票名称    170816 non-null  object
#  12  板块名称    170816 non-null  object
#  13  总股本     170816 non-null  float64
#  14  总市值     170816 non-null  float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 20.9+ MB

# %%
merge_data = merge_df.loc["2023-03-24"]
merge_data
# Out:
#                开盘     收盘     最高     最低     成交量          成交额    振幅   涨跌幅   涨跌额  \
# 日期
# 2023-03-24  20.40  21.03  21.23  20.30   46779   97837140.1  4.56  3.09  0.63
# 2023-03-24  20.40  21.03  21.23  20.30   46779   97837140.1  4.56  3.09  0.63
# 2023-03-24   4.31   4.33   4.35   4.30   52031   22498401.0  1.16  0.23  0.01
# 2023-03-24   4.31   4.33   4.35   4.30   52031   22498401.0  1.16  0.23  0.01
# 2023-03-24   4.91   4.85   4.91   4.84   91069   44265053.0  1.42 -1.42 -0.07
# ...           ...    ...    ...    ...     ...          ...   ...   ...   ...
# 2023-03-24  15.06  14.98  15.06  14.87    2286    3420938.0  1.27  0.20  0.03
# 2023-03-24   3.91   3.94   4.00   3.89   75331   29660289.0  2.80  0.25  0.01
# 2023-03-24  10.25  10.25  10.31  10.20  141095  144551683.0  1.07  0.00  0.00
# 2023-03-24  10.01  10.05  10.11   9.96  119530  120025603.6  1.49  0.10  0.01
# 2023-03-24  13.02  13.12  13.23  13.02   24333   31929546.0  1.61  0.61  0.08
#
# ...

# %%
# 603777
merge_data[merge_data['股票代码'] == "603777"]
# Out:
#                开盘     收盘     最高     最低    成交量         成交额    振幅   涨跌幅   涨跌额  \
# 日期
# 2023-03-24  17.95  17.89  18.19  17.78  26871  48263461.0  2.28 -0.33 -0.06
# 2023-03-24  17.95  17.89  18.19  17.78  26871  48263461.0  2.28 -0.33 -0.06
#
#             换手率    股票代码 股票名称    板块名称          总股本           总市值
# 日期
# 2023-03-24  0.8  603777  来伊份  食品加工制造  336559908.0  6.021057e+09
# 2023-03-24  0.8  603777  来伊份    休闲食品  336559908.0  6.021057e+09

# %%
merge_data['板块名称'].unique()
# Out:
# array(['农业服务', '动物保健', '农业综合', '养殖业', '畜禽养殖', '水产养殖', '海洋捕捞', '煤炭开采加工',
#        '煤炭开采', '焦炭加工', '种植业与林业', '其他种植业', '林业', '种子生产', '粮食种植', '油气开采及服务',
#        '油服工程', '油气开采', '燃气Ⅲ', '农产品加工', '饲料', '粮油加工', '果蔬加工', '其他农产品加工',
#        '化学原料', '其他化学原料', '氯碱', '无机盐', '纯碱', '钛白粉', '金属新材料', '其他金属新材料',
#        '磁性材料', '钢铁', '普钢', '特钢', '冶钢原料', '非金属材料Ⅲ', '化工合成材料', '膜材料',
#        '改性塑料', '其他橡胶制品', '涤纶', '其他塑料制品', '合成树脂', '炭黑', '其他纤维', '粘胶', '氨纶',
#        '建筑材料', '玻璃玻纤', '其他建材', '水泥', '管材', '耐火材料', '化学制品', '涂料油墨',
#        '其他化学制品', '聚氨酯', '有机硅', '农药', '食品及饲料添加剂', '磷肥及磷化工', '纺织化学用品', '钾肥',
#        '民爆用品', '氟化工', '氮肥', '复合肥', '仪器仪表', '建筑装饰', '工程咨询服务', '装饰园林',
#        '专业工程', '基础建设', '房屋建设', '通用设备', '金属制品', '其他通用设备', '机床工具', '磨具磨料',
#        '制冷空调设备', '其他电子', '专用设备', '其他专用设备', '能源及重型设备', '农用机械', '工程机械',
#        '楼宇设备', '印刷包装机械', '纺织服装设备', '光学光电子', '光学元件', 'LED', '面板', '小家电Ⅲ',
#        '汽车整车', '商用载货车', '乘用车', '商用载客车', '消费电子', '消费电子零部件及组装', '品牌消费电子',
# ...

# %%
ag_data=merge_data[merge_data['板块名称']=="农业服务"]
ag_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 16 entries, 2023-03-24 to 2023-03-24
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   开盘      16 non-null     float64
#  1   收盘      16 non-null     float64
#  2   最高      16 non-null     float64
#  3   最低      16 non-null     float64
#  4   成交量     16 non-null     int64
#  5   成交额     16 non-null     float64
#  6   振幅      16 non-null     float64
#  7   涨跌幅     16 non-null     float64
#  8   涨跌额     16 non-null     float64
#  9   换手率     16 non-null     float64
#  10  股票代码    16 non-null     object
#  11  股票名称    16 non-null     object
#  12  板块名称    16 non-null     object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ KB

# %%
ag_data['股票代码'].unique()
# Out:
# array(['300119', '002141', '300021', '600201', '688098', '300871',
#        '603718', '600195', '002556', '838275', '839729', '830964',
#        '002688', '603566', '002868', '688526'], dtype=object)

# %%
ag_data.isnull().sum()
# Out:
# 开盘      0
# 收盘      0
# 最高      0
# 最低      0
# 成交量     0
# 成交额     0
# 振幅      0
# 涨跌幅     0
# 涨跌额     0
# 换手率     0
# 股票代码    0
# 股票名称    0
# 板块名称    0
# dtype: int64

# %%
value = pd.read_csv("../data/总股本.csv", index_col=0, dtype={"股票代码": object})
value.isnull().sum()
# Out:
# 总股本    183
# dtype: int64

# %%
value.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5077 entries, 688018 to 601992
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   总股本     4894 non-null   float64
# dtypes: float64(1)
# memory usage: 79.3+ KB

# %%
value = pd.read_csv("../data/总股本.csv", index_col=0, dtype={"股票代码": object})
value_dict = value['总股本'].to_dict()
value_dict
# Out:
# {'688018': 80484430.0,
#  '600486': 309898907.0,
#  '301380': 68000000.0,
#  '301369': 46400179.0,
#  '002629': 436648000.0,
#  '001217': 331870000.0,
#  '300725': 199664227.0,
#  '002975': 139380126.0,
#  '002748': 240000000.0,
#  '002036': 1073347092.0,
#  '688323': 180000000.0,
#  '688233': 160000000.0,
#  '603758': 438797049.0,
#  '603615': 241820000.0,
#  '603267': 232400000.0,
#  '601608': 4339419293.0,
#  '600865': 376240316.0,
#  '600861': 316804949.0,
#  '600719': 404599600.0,
#  '600507': 2331805223.0,
#  '600408': 1006800000.0,
#  '600388': 1071464473.0,
#  '600332': 1405890949.0,
#  '600168': 709569692.0,
#  '301226': 68000000.0,
#  '301049': 94253334.0,
#  '300346': 543702550.0,
#  '300286': 214716125.0,
#  '300211': 303359723.0,
#  '300146': 1700362763.0,
#  '300087': 676665537.0,
#  '300059': 13214162544.0,
#  '300006': 1055911205.0,
#  '002972': 176320000.0,
#  '002879': 193107640.0,
#  '002419': 1168847750.0,
#  '002321': 2132890071.0,
#  '002233': 1192275016.0,
# ...

# %%
my_list = ag_data['股票代码'].unique().tolist()
# my_dict = {1: 'apple', 2: 'banana', 3: 'orange'}

not_in_dict_list = []

for elem in my_list:
    if elem not in value_dict.keys():
        not_in_dict_list.append(elem)
    else:
        print(f'{elem}--->{value_dict.get(elem)}')

print("不在字典key中的元素：", not_in_dict_list)
# Out:
# 300119--->468018786.0
# 002141--->1134656519.0
# 300021--->862298764.0
# 600201--->1120369226.0
# 688098--->410644000.0
# 300871--->166054034.0
# 603718--->644000000.0
# 600195--->1021148260.0
# 002556--->953992980.0
# 838275--->nan
# 839729--->nan
# 830964--->nan
# 002688--->780422398.0
# 603566--->352916573.0
# 002868--->155415837.0
# 688526--->465133200.0
# 不在字典key中的元素： []

# %%
code_df = pd.read_csv(
    "../data/板块名称_股票对应.csv", index_col=0, dtype={"股票代码": object})
# code_dict = code_df.set_index("代码")['板块名称'].to_dict()

code_list=code_df['股票代码'].unique().tolist()
len(code_list)
# Out:
# 5120

# %%
5120-5097
# Out:
# 23

# %%
code_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9537 entries, 0 to 9554
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   股票代码    9537 non-null   object
#  1   股票名称    9537 non-null   object
#  2   板块名称    9537 non-null   object
# dtypes: object(3)
# memory usage: 298.0+ KB

# %%
total_df = pd.read_csv("../data/总股本_em.csv",
                    index_col=["股票代码"], dtype={"股票代码": object})
total_df.index.nunique()
# Out:
# 5097

# %%
total_list=total_df.index.unique().tolist()
total_list[0]
# Out:
# '300119'

# %%
result_list = [x for x in total_list if x not in code_list]
result_list
# Out:
# []

# %%
len(result_list)
# Out:
# 0

# %%
result_list = [x for x in code_list if x not in total_list]
result_list
# Out:
# ['300728',
#  '002021',
#  '000157',
#  '836720',
#  '002857',
#  '600885',
#  '300444',
#  '002962',
#  '300964',
#  '002260',
#  '002473',
#  '600664',
#  '000788',
#  '002435',
#  '002755',
#  '600488',
#  '600856',
#  '000835',
#  '002619',
#  '600652',
#  '605077',
#  '300870',
#  '688123']

# %%
len(result_list)
# Out:
# 23

# %%
import akshare as ak

temp_df = ak.stock_individual_info_em('002021')
temp_df
# Out:
#    item         value
# 0   总市值  1334361177.6
# 1  流通市值  1334317527.6
# 2    行业          专用设备
# 3  上市时间      20040715
# 4  股票代码        002021
# 5  股票简称          ST中捷
# 6   总股本   687815040.0
# 7   流通股   687792540.0

# %%
import akshare as ak

temp_df1 = ak.stock_individual_info_em('000157')
temp_df1
# Out:
#    item               value
# 0   总市值  54063891630.280006
# 1  流通市值  44038169104.090004
# 2    行业                工程机械
# 3  上市时间            20001012
# 4  股票代码              000157
# 5  股票简称                中联重科
# 6   总股本        8677992236.0
# 7   流通股        7068726983.0

# %%
# 836720

# %%
code_dict = dict()
code_df = pd.read_csv(
    "../data/板块名称_股票对应.csv", index_col=0, dtype={"股票代码": object})
code_dict = code_df.set_index("股票代码")['板块名称'].to_dict()
my_list = ['300728',
           '002021',
           '000157',
           '836720',
           '002857',
           '600885',
           '300444',
           '002962',
           '300964',
           '002260',
           '002473',
           '600664',
           '000788',
           '002435',
           '002755',
           '600488',
           '600856',
           '000835',
           '002619',
           '600652',
           '605077',
           '300870',
           '688123']
result_dict = {}
result_dict = {x: code_dict.get(x) for x in my_list}
result_dict
# Out:
# {'300728': '非金属材料Ⅲ',
#  '002021': '纺织服装设备',
#  '000157': '工程机械',
#  '836720': '工程机械',
#  '002857': '电气自控设备',
#  '600885': '输变电设备',
#  '300444': '输变电设备',
#  '002962': '光学元件',
#  '300964': '印制电路板',
#  '002260': '小家电Ⅲ',
#  '002473': '小家电Ⅲ',
#  '600664': '化学制剂',
#  '000788': '化学制剂',
#  '002435': '化学制剂',
#  '002755': '化学制剂',
#  '600488': '化学制剂',
#  '600856': '燃气Ⅲ',
#  '000835': '其他传媒',
#  '002619': '其他传媒',
#  '600652': '其他传媒',
#  '605077': '食品及饲料添加剂',
#  '300870': '其他电源设备',
#  '688123': '集成电路设计'}

# %%
code_dict
# Out:
# {'300119': '动物保健',
#  '002141': '动物保健',
#  '300021': '农业综合',
#  '600201': '动物保健',
#  '688098': '动物保健',
#  '300871': '动物保健',
#  '603718': '动物保健',
#  '600195': '动物保健',
#  '002556': '农业综合',
#  '838275': '动物保健',
#  '839729': '动物保健',
#  '830964': '农业综合',
#  '002688': '动物保健',
#  '603566': '动物保健',
#  '002868': '动物保健',
#  '688526': '动物保健',
#  '300761': '畜禽养殖',
#  '000735': '畜禽养殖',
#  '002157': '畜禽养殖',
#  '001201': '畜禽养殖',
#  '002714': '畜禽养殖',
#  '002069': '水产养殖',
#  '605296': '畜禽养殖',
#  '300967': '畜禽养殖',
#  '002124': '畜禽养殖',
#  '002982': '畜禽养殖',
#  '603477': '畜禽养殖',
#  '600097': '海洋捕捞',
#  '300498': '畜禽养殖',
#  '600965': '畜禽养殖',
#  '002299': '畜禽养殖',
#  '600975': '畜禽养殖',
#  '600467': '水产养殖',
#  '600257': '水产养殖',
#  '002321': '畜禽养殖',
#  '300094': '水产养殖',
#  '002234': '畜禽养殖',
#  '002458': '畜禽养殖',
#  '000798': '海洋捕捞',
#  '002746': '畜禽养殖',
#  '300313': '畜禽养殖',
#  '600758': '煤炭开采',
#  '601225': '煤炭开采',
#  '600971': '煤炭开采',
#  '601699': '煤炭开采',
#  '600397': '煤炭开采',
#  '601918': '煤炭开采',
# ...
